# %%
# !nvidia-smi

# %%
# !pip install -U pandas
# !pip install -U setuptools wheel
# !pip install -U mxnet-cu112
# !pip install autogluon
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement mxnet-cu112
# ERROR: No matching distribution found for mxnet-cu112
# ...

# %%
from autogluon.tabular import TabularPredictor

# %%
# import pickle
import pandas as pd
import os

# %%
train_data = pd.read_csv('../DATA/train_normalized_4labels.csv', index_col=0, encoding = 'ISO-8859-1')
# Out:
# /Users/renayang/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/arraysetops.py:583: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)

# %%
# !pip install pandas --upgrade

# %%
predictor = TabularPredictor(
    label='CASE_STATUS', eval_metric='balanced_accuracy').fit(train_data)
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20211205_052119/"
# ...
# 	Consider setting `time_limit` to ensure training finishes within an expected duration or experiment with a small portion of `train_data` to identify an ideal `presets` and `hyperparameters` configuration.
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/ag-20211205_052119/"
# AutoGluon Version:  0.3.1
# Train Data Rows:    1704571
# Train Data Columns: 421
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'multiclass' (because dtype of label-column == object).
# 	4 unique label values:  ['CERTIFIED', 'CERTIFIED-WITHDRAWN', 'DENIED', 'WITHDRAWN']
# 	If 'multiclass' is not the correct problem_type, please manually specify the problem_type argument in fit() (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Train Data Class Count: 4
# Using Feature Generators to preprocess the data ...
# ...

# %%
test_data = pd.read_csv('../DATA/test_normalized_4labels.csv',index_col=0)

# %%
predictor.leaderboard(test_data)
# Out:
#                  model  score_test  score_val  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0             LightGBM    0.811467   0.811420       12.440982       0.235466   142.916335                12.440982                0.235466         142.916335            1       True          5
# 1             CatBoost    0.809525   0.816640        1.653148       0.145886   339.852476                 1.653148                0.145886         339.852476            1       True          6
# 2  WeightedEnsemble_L2    0.808518   0.826991      445.069666      10.359121  4456.158557                 0.288157                0.004001           3.762052            2       True          9
# 3              XGBoost    0.801699   0.804532       11.506559       0.204061    51.296466                11.506559                0.204061          51.296466            1       True          7
# ...
